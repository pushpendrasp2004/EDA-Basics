# %% [markdown]
# Q1. Average, Median, and Standard Deviation of House Prices
# Average Price (Mean): ₹538,932
# Median Price: ₹450,000
# Standard Deviation: ₹367,532
#
# Interpretation:
#
# Mean > Median → prices are positively skewed (few very expensive houses raise the average).
# High standard deviation indicates large variation in house prices.
#
# Q2. Most Common Number of Bedrooms
# Most common: 3 bedrooms
#
# Interpretation:
#
# 3-bedroom houses are the most preferred or most available in the dataset.
# Q3. Check if Price Data is Skewed
# Skewness value: +4.27
#
# Interpretation:
#
# Strong positive skewness
# Many houses are moderately priced, but a few very expensive outliers exist.
# Q4. Average Price for Each Number of Bedrooms
#
# (Example summary)
#
# 1–2 bedrooms → Lower average prices
# 3 bedrooms → Moderate price range
# 4+ bedrooms → Higher average prices
#
# Interpretation:
#
# Price increases with number of bedrooms, showing a strong demand-value relationship.
# Q5. Relationship Between Living Area and Price
# Correlation: +0.615
#
# Interpretation:
#
# Moderate to strong positive relationship
# Larger house area → Higher price
# Area is an important price-determining factor
# Q6. Anomalies (High Price but Low Area)
#
# Example anomaly:
#
# Price ≈ ₹990,000 with area ≈ 930 sq ft
#
# Interpretation:
#
# These houses may have:
# Premium location
# Luxury features
# Waterfront or high-grade construction
# Q7. Price Based on Floors & Waterfront
# Houses with waterfront = 1 → significantly higher prices
# More floors → generally higher prices
#
# Interpretation:
#
# Waterfront property is a major price driver
# Multi-floor houses tend to be more valuable
# Q8. Minimum and Maximum Price
# Minimum Price: ₹78,000
# Maximum Price: ₹7,700,000
#
# Interpretation:
#
# Huge price range → market includes:
# Budget homes
# Luxury/high-end properties
# Q9. Location with Highest Average Price
# Postal Code: 122071
# Average Price: ₹2,348,310
#
# Interpretation:
#
# This area is likely a premium or high-demand location
# Q10. Final Insights (Key Business Insights)
# House prices are highly skewed, with luxury properties driving the average up.
# 3-bedroom houses dominate the market, indicating standard family demand.
# Living area strongly influences price, making it a key pricing factor.
# Waterfront properties significantly increase value, making them premium assets.
# Certain locations (e.g., Postal Code 122071) are high-value investment zones.
# Large variation in price suggests a diverse housing market (budget to luxury).
# Some anomalies indicate hidden value factors like location or amenities.
